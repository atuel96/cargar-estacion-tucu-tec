# %% [markdown]
# # 02 - Add SYM Data
#
# Agregamos SYM

# %%
import pandas as pd
import polars as pl
import numpy as np
import matplotlib.pyplot as plt 

from pathlib import Path 
from data_utils import load_symh_data


datapath = Path("sym/ASY_2017-01-01_2017-12-31h_P.dat")
symh = load_symh_data(datapath)

# %%
plt.plot(symh)

# %%
from datetime import datetime, timedelta
symh_resampled = symh.resample(rule=timedelta(0,30)).ffill()
