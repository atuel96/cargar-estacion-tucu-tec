# %% [markdown]
# # 01 - Read TEC Data
#
# Notebook para cargar los datos usando las funciones de `data_utils.py` y mostrar algunas estadisticas

# %%
import numpy as np
import pandas as pd
import polars as pl
import matplotlib.pyplot as plt

from pathlib import Path 
import logging

# Set logging
logger = logging.getLogger()
logger.setLevel(logging.WARN)

# %%
from data_utils import load_tec_data

# Load Data
datafolder = Path("tucu")
year = 2017
df = load_tec_data(year, datafolder)

# %%
df
# Out:
#                      seconds    TEC  DOY  year
# datetime
# 2017-01-01 00:00:00        0  21.05    1  2017
# 2017-01-01 00:00:15       15  21.02    1  2017
# 2017-01-01 00:00:30       30  20.98    1  2017
# 2017-01-01 00:00:45       45  20.95    1  2017
# 2017-01-01 00:01:00       60  20.91    1  2017
# ...                      ...    ...  ...   ...
# 2017-05-30 23:58:45    86325    NaN  150  2017
# 2017-05-30 23:59:00    86340    NaN  150  2017
# 2017-05-30 23:59:15    86355    NaN  150  2017
# 2017-05-30 23:59:30    86370    NaN  150  2017
# 2017-05-30 23:59:45    86385    NaN  150  2017
#
# [864000 rows x 4 columns]

# %%
from data_utils import basic_stats

basic_stats(df.TEC)
# Out:
# Tamaño de la serie: 864000
# Porcentaje de NaNs: 8.727%
# 75405 NaNs y 788595 Valores no nulos.
# array([<Axes: >, <Axes: >], dtype=object)

# %%
import matplotlib.pyplot as plt 

plt.plot(df.index,df.TEC)

# %%
daily_average = df.groupby("DOY").mean()
plt.plot(daily_average.index, daily_average.TEC)
