# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

from pathlib import Path
from datetime import timedelta

import data_utils

# %%
years = [2000, 2001, 2002, 2003, 2004, 2005, 2017]
processed_data = Path("processed_data/")
for year in years:
    year_folder = processed_data / str(year)
    year_folder.mkdir(parents=True, exist_ok=True)

    # tec
    tec = pd.read_csv(f"parsed_data/tucu-year-{year}.csv", index_col=0, parse_dates=True)

    # resample & fill tec
    tec = tec.resample(rule=timedelta(0,60)).asfreq() # resample to 60s
    tec = tec.interpolate(method="linear", limit=10) # interpolate missing values with gaps shorter than 10 minutes
    
    # create groups separating by nans
    tec["group"] = tec.isnull().all(axis=1).cumsum()

    # symh 
    symh = data_utils.load_symh_wdc(f"sym/ASY-SYM-WDCformat-{year}.dat")

    groups = tec.group.max()
    min_tec_samples = 1440*2
    for group in range(groups+1):
        no_of_tecs = tec.loc[tec.group == group].count().tec

        if no_of_tecs <= min_tec_samples:
            continue 
        print(group, no_of_tecs)

        group_tec = tec.loc[tec.group == group].dropna()
        start_date = group_tec.index[0].to_pydatetime()
        end_date = group_tec.index[-1].to_pydatetime()
        
        df = pd.merge(left=group_tec, 
            right=symh, 
            right_on=symh.index, 
            how="left",left_index=True).loc[:,["tec", "symh"]]
        filename = f"tec-symh-{start_date.strftime("%Y-%m-%d")}-{end_date.strftime("%Y-%m-%d")}.csv"
        filepath = year_folder / filename
        df.to_csv(filepath)
        print(filepath, "saved!")
# Out:
# 1 70993
# processed_data/2000/tec-symh-2000-01-01-2000-02-19.csv saved!
# 129 56534
# processed_data/2000/tec-symh-2000-02-19-2000-03-29.csv saved!
# 154 27849
# processed_data/2000/tec-symh-2000-03-29-2000-04-18.csv saved!
# 1585 21609
# processed_data/2000/tec-symh-2000-04-19-2000-05-04.csv saved!
# 3016 193538
# processed_data/2000/tec-symh-2000-05-05-2000-09-16.csv saved!
# 3018 17230
# processed_data/2000/tec-symh-2000-09-16-2000-09-28.csv saved!
# 3153 14312
# processed_data/2000/tec-symh-2000-09-29-2000-10-09.csv saved!
# 3221 120355
# processed_data/2000/tec-symh-2000-10-09-2000-12-31.csv saved!
# 1 17289
# processed_data/2001/tec-symh-2001-01-01-2001-01-13.csv saved!
# 1432 12969
# processed_data/2001/tec-symh-2001-01-14-2001-01-23.csv saved!
# 33998 6132
# processed_data/2001/tec-symh-2001-02-14-2001-02-18.csv saved!
# 34171 16318
# processed_data/2001/tec-symh-2001-02-19-2001-03-02.csv saved!
# 34591 9822
# processed_data/2001/tec-symh-2001-03-04-2001-03-11.csv saved!
# 34892 5656
# processed_data/2001/tec-symh-2001-03-12-2001-03-16.csv saved!
# 34955 12848
# processed_data/2001/tec-symh-2001-03-16-2001-03-25.csv saved!
# 35903 33919
# processed_data/2001/tec-symh-2001-03-26-2001-04-18.csv saved!
# 36000 29353
# processed_data/2001/tec-symh-2001-04-18-2001-05-09.csv saved!
# 150923 3980
# processed_data/2001/tec-symh-2001-07-27-2001-07-30.csv saved!
# 150939 5724
# processed_data/2001/tec-symh-2001-07-30-2001-08-03.csv saved!
# 151567 8207
# processed_data/2001/tec-symh-2001-08-04-2001-08-09.csv saved!
# 152052 7809
# processed_data/2001/tec-symh-2001-08-10-2001-08-16.csv saved!
# 154923 7209
# processed_data/2017/tec-symh-2017-04-09-2017-04-21.csv saved!
# 14680 2967
# processed_data/2017/tec-symh-2017-04-22-2017-04-24.csv saved!
# 16033 3857
# processed_data/2017/tec-symh-2017-04-25-2017-04-27.csv saved!
# 16496 5082
# processed_data/2017/tec-symh-2017-04-28-2017-05-01.csv saved!
# 17174 29979
# processed_data/2017/tec-symh-2017-05-02-2017-05-22.csv saved!
# 17435 10351
# processed_data/2017/tec-symh-2017-05-23-2017-05-30.csv saved!

# %%
# resample processed data
data_path = Path("processed_data/")

for year_folder in data_path.iterdir():
    if not year_folder.is_dir():
        continue
    print(year_folder)
    for df_path in year_folder.iterdir():
        if df_path.suffix != ".csv":
            continue
        if "5min" in df_path.name or "10min" in df_path.name:
            continue
        print(df_path, "starting ...")
        df = pd.read_csv(df_path, index_col=0, parse_dates=True)
        df_10min = df.resample(rule=timedelta(minutes=10)).asfreq().dropna()
        df_5min = df.resample(rule=timedelta(minutes=5)).asfreq().dropna()
        df_10min.to_csv(df_path.parent / (str(df_path.with_suffix("").name) + "-freq-10min.csv"))
        df_5min.to_csv(df_path.parent / (str(df_path.with_suffix("").name) + "-freq-5min.csv"))
        print(df_path, "done!")
# Out:
# processed_data/2004
# processed_data/2004/tec-symh-2004-07-08-2004-07-11.csv starting ...
# processed_data/2004/tec-symh-2004-07-08-2004-07-11.csv done!
# processed_data/2004/tec-symh-2004-01-01-2004-03-17.csv starting ...
# processed_data/2004/tec-symh-2004-01-01-2004-03-17.csv done!
# processed_data/2004/tec-symh-2004-10-27-2004-12-27.csv starting ...
# processed_data/2004/tec-symh-2004-10-27-2004-12-27.csv done!
# processed_data/2004/tec-symh-2004-10-02-2004-10-05.csv starting ...
# processed_data/2004/tec-symh-2004-10-02-2004-10-05.csv done!
# processed_data/2004/tec-symh-2004-07-22-2004-07-27.csv starting ...
# processed_data/2004/tec-symh-2004-07-22-2004-07-27.csv done!
# processed_data/2004/tec-symh-2004-09-24-2004-10-01.csv starting ...
# processed_data/2004/tec-symh-2004-09-24-2004-10-01.csv done!
# processed_data/2004/tec-symh-2004-04-22-2004-05-31.csv starting ...
# processed_data/2004/tec-symh-2004-04-22-2004-05-31.csv done!
# processed_data/2004/tec-symh-2004-10-06-2004-10-27.csv starting ...
# processed_data/2004/tec-symh-2004-10-06-2004-10-27.csv done!
# processed_data/2004/tec-symh-2004-09-07-2004-09-23.csv starting ...
# processed_data/2004/tec-symh-2004-09-07-2004-09-23.csv done!
# processed_data/2004/tec-symh-2004-07-27-2004-08-11.csv starting ...
# processed_data/2004/tec-symh-2004-07-27-2004-08-11.csv done!
# processed_data/2004/tec-symh-2004-03-18-2004-04-22.csv starting ...
# processed_data/2004/tec-symh-2004-03-18-2004-04-22.csv done!
# processed_data/2004/tec-symh-2004-08-20-2004-09-06.csv starting ...
# processed_data/2004/tec-symh-2004-08-20-2004-09-06.csv done!
# processed_data/2017
# processed_data/2017/tec-symh-2017-02-01-2017-02-08.csv starting ...
# processed_data/2017/tec-symh-2017-02-01-2017-02-08.csv done!
# processed_data/2017/tec-symh-2017-05-23-2017-05-30.csv starting ...
# processed_data/2017/tec-symh-2017-05-23-2017-05-30.csv done!
# processed_data/2017/tec-symh-2017-02-09-2017-02-13.csv starting ...
# processed_data/2002/tec-symh-2002-11-05-2002-11-16.csv done!
# processed_data/2002/tec-symh-2002-08-22-2002-09-02.csv starting ...
# processed_data/2002/tec-symh-2002-08-22-2002-09-02.csv done!
# processed_data/2002/tec-symh-2002-02-22-2002-02-26.csv starting ...
# processed_data/2002/tec-symh-2002-02-22-2002-02-26.csv done!
# processed_data/2002/tec-symh-2002-02-06-2002-02-12.csv starting ...
# processed_data/2002/tec-symh-2002-02-06-2002-02-12.csv done!
# processed_data/2002/tec-symh-2002-01-10-2002-01-17.csv starting ...
# processed_data/2002/tec-symh-2002-01-10-2002-01-17.csv done!
# processed_data/2002/tec-symh-2002-05-28-2002-05-31.csv starting ...
# processed_data/2002/tec-symh-2002-05-28-2002-05-31.csv done!
# processed_data/2002/tec-symh-2002-05-22-2002-05-28.csv starting ...
# processed_data/2002/tec-symh-2002-05-22-2002-05-28.csv done!
# processed_data/2002/tec-symh-2002-01-24-2002-01-31.csv starting ...
# processed_data/2002/tec-symh-2002-01-24-2002-01-31.csv done!
# processed_data/2002/tec-symh-2002-01-31-2002-02-06.csv starting ...
# processed_data/2002/tec-symh-2002-01-31-2002-02-06.csv done!
# processed_data/2002/tec-symh-2002-11-19-2002-11-26.csv starting ...
# processed_data/2002/tec-symh-2002-11-19-2002-11-26.csv done!
# processed_data/2002/tec-symh-2002-10-27-2002-10-30.csv starting ...
# processed_data/2002/tec-symh-2002-10-27-2002-10-30.csv done!
# processed_data/2002/tec-symh-2002-01-05-2002-01-10.csv starting ...
# processed_data/2002/tec-symh-2002-01-05-2002-01-10.csv done!
# processed_data/2002/tec-symh-2002-02-14-2002-02-18.csv starting ...
# processed_data/2002/tec-symh-2002-02-14-2002-02-18.csv done!
# processed_data/2002/tec-symh-2002-05-31-2002-06-04.csv starting ...
# processed_data/2002/tec-symh-2002-05-31-2002-06-04.csv done!
# processed_data/2002/tec-symh-2002-09-02-2002-09-18.csv starting ...
# processed_data/2002/tec-symh-2002-09-02-2002-09-18.csv done!
# processed_data/2000
# processed_data/2000/tec-symh-2000-03-29-2000-04-18.csv starting ...
# processed_data/2000/tec-symh-2000-03-29-2000-04-18.csv done!
# processed_data/2000/tec-symh-2000-10-09-2000-12-31.csv starting ...
# processed_data/2000/tec-symh-2000-10-09-2000-12-31.csv done!
# processed_data/2000/tec-symh-2000-09-29-2000-10-09.csv starting ...
# processed_data/2000/tec-symh-2000-09-29-2000-10-09.csv done!
# processed_data/2000/tec-symh-2000-09-16-2000-09-28.csv starting ...
# processed_data/2000/tec-symh-2000-09-16-2000-09-28.csv done!
# processed_data/2000/tec-symh-2000-05-05-2000-09-16.csv starting ...
# processed_data/2000/tec-symh-2000-05-05-2000-09-16.csv done!
# processed_data/2000/tec-symh-2000-02-19-2000-03-29.csv starting ...
# processed_data/2000/tec-symh-2000-02-19-2000-03-29.csv done!
# processed_data/2000/tec-symh-2000-04-19-2000-05-04.csv starting ...
# processed_data/2000/tec-symh-2000-04-19-2000-05-04.csv done!
# processed_data/2000/tec-symh-2000-01-01-2000-02-19.csv starting ...
# processed_data/2000/tec-symh-2000-01-01-2000-02-19.csv done!
# processed_data/2001
# processed_data/2001/tec-symh-2001-04-18-2001-05-09.csv starting ...
# processed_data/2001/tec-symh-2001-04-18-2001-05-09.csv done!
# processed_data/2001/tec-symh-2001-11-01-2001-11-05.csv starting ...
# processed_data/2001/tec-symh-2001-11-01-2001-11-05.csv done!
# processed_data/2001/tec-symh-2001-01-01-2001-01-13.csv starting ...
# processed_data/2001/tec-symh-2001-01-01-2001-01-13.csv done!
# processed_data/2001/tec-symh-2001-07-30-2001-08-03.csv starting ...
# processed_data/2001/tec-symh-2001-07-30-2001-08-03.csv done!
# processed_data/2001/tec-symh-2001-08-10-2001-08-16.csv starting ...
# processed_data/2001/tec-symh-2001-08-10-2001-08-16.csv done!
# processed_data/2001/tec-symh-2001-01-14-2001-01-23.csv starting ...
# processed_data/2001/tec-symh-2001-01-14-2001-01-23.csv done!
# processed_data/2001/tec-symh-2001-10-10-2001-10-15.csv starting ...
# processed_data/2001/tec-symh-2001-10-10-2001-10-15.csv done!
# processed_data/2001/tec-symh-2001-11-16-2001-11-21.csv starting ...
# processed_data/2001/tec-symh-2001-11-16-2001-11-21.csv done!
# processed_data/2001/tec-symh-2001-09-28-2001-10-03.csv starting ...
# processed_data/2001/tec-symh-2001-09-28-2001-10-03.csv done!
# processed_data/2001/tec-symh-2001-10-07-2001-10-10.csv starting ...
# processed_data/2001/tec-symh-2001-10-07-2001-10-10.csv done!
# processed_data/2001/tec-symh-2001-03-16-2001-03-25.csv starting ...
# processed_data/2001/tec-symh-2001-03-16-2001-03-25.csv done!
# processed_data/2001/tec-symh-2001-08-25-2001-08-30.csv starting ...
# processed_data/2001/tec-symh-2001-08-25-2001-08-30.csv done!
# processed_data/2001/tec-symh-2001-03-26-2001-04-18.csv starting ...
# processed_data/2001/tec-symh-2001-03-26-2001-04-18.csv done!
# processed_data/2001/tec-symh-2001-11-26-2001-12-03.csv starting ...
# processed_data/2001/tec-symh-2001-11-26-2001-12-03.csv done!
# processed_data/2001/tec-symh-2001-08-04-2001-08-09.csv starting ...
# processed_data/2001/tec-symh-2001-08-04-2001-08-09.csv done!
# processed_data/2001/tec-symh-2001-02-14-2001-02-18.csv starting ...
# processed_data/2001/tec-symh-2001-02-14-2001-02-18.csv done!
# processed_data/2001/tec-symh-2001-11-05-2001-11-12.csv starting ...
# processed_data/2001/tec-symh-2001-11-05-2001-11-12.csv done!
# processed_data/2001/tec-symh-2001-11-21-2001-11-26.csv starting ...
# processed_data/2001/tec-symh-2001-11-21-2001-11-26.csv done!
# processed_data/2001/tec-symh-2001-12-21-2001-12-26.csv starting ...
# processed_data/2001/tec-symh-2001-12-21-2001-12-26.csv done!
# processed_data/2001/tec-symh-2001-12-12-2001-12-14.csv starting ...
# processed_data/2001/tec-symh-2001-12-12-2001-12-14.csv done!
# processed_data/2001/tec-symh-2001-10-23-2001-10-29.csv starting ...
# processed_data/2001/tec-symh-2001-10-23-2001-10-29.csv done!
# processed_data/2001/tec-symh-2001-02-19-2001-03-02.csv starting ...
# processed_data/2001/tec-symh-2001-02-19-2001-03-02.csv done!
# processed_data/2001/tec-symh-2001-10-29-2001-11-01.csv starting ...
# processed_data/2001/tec-symh-2001-10-29-2001-11-01.csv done!
# processed_data/2001/tec-symh-2001-11-12-2001-11-16.csv starting ...
# processed_data/2001/tec-symh-2001-11-12-2001-11-16.csv done!
# processed_data/2001/tec-symh-2001-12-14-2001-12-17.csv starting ...
# processed_data/2001/tec-symh-2001-12-14-2001-12-17.csv done!
# processed_data/2001/tec-symh-2001-03-04-2001-03-11.csv starting ...
# processed_data/2001/tec-symh-2001-03-04-2001-03-11.csv done!
# processed_data/2001/tec-symh-2001-07-27-2001-07-30.csv starting ...
# processed_data/2001/tec-symh-2001-07-27-2001-07-30.csv done!
# processed_data/2001/tec-symh-2001-12-06-2001-12-10.csv starting ...
# processed_data/2001/tec-symh-2001-12-06-2001-12-10.csv done!
# processed_data/2001/tec-symh-2001-12-03-2001-12-06.csv starting ...
# processed_data/2001/tec-symh-2001-12-03-2001-12-06.csv done!
# processed_data/2001/tec-symh-2001-03-12-2001-03-16.csv starting ...
# processed_data/2001/tec-symh-2001-03-12-2001-03-16.csv done!
# processed_data/2001/tec-symh-2001-08-18-2001-08-23.csv starting ...
# processed_data/2001/tec-symh-2001-08-18-2001-08-23.csv done!
# processed_data/2001/tec-symh-2001-10-03-2001-10-06.csv starting ...
# processed_data/2001/tec-symh-2001-10-03-2001-10-06.csv done!
# processed_data/2003
# processed_data/2003/tec-symh-2003-02-18-2003-02-26.csv starting ...
# processed_data/2003/tec-symh-2003-02-18-2003-02-26.csv done!
# processed_data/2003/tec-symh-2003-01-29-2003-02-03.csv starting ...
# processed_data/2003/tec-symh-2003-01-29-2003-02-03.csv done!
# processed_data/2003/tec-symh-2003-03-07-2003-05-02.csv starting ...
# processed_data/2003/tec-symh-2003-03-07-2003-05-02.csv done!
# processed_data/2003/tec-symh-2003-10-28-2003-11-11.csv starting ...
# processed_data/2003/tec-symh-2003-10-28-2003-11-11.csv done!
# processed_data/2003/tec-symh-2003-11-22-2003-12-30.csv starting ...
# processed_data/2003/tec-symh-2003-11-22-2003-12-30.csv done!
# processed_data/2003/tec-symh-2003-01-02-2003-01-29.csv starting ...
# processed_data/2003/tec-symh-2003-01-02-2003-01-29.csv done!
# processed_data/2003/tec-symh-2003-09-26-2003-10-25.csv starting ...
# processed_data/2003/tec-symh-2003-09-26-2003-10-25.csv done!
# processed_data/2003/tec-symh-2003-02-04-2003-02-13.csv starting ...
# processed_data/2003/tec-symh-2003-02-04-2003-02-13.csv done!
# processed_data/2003/tec-symh-2003-05-30-2003-09-26.csv starting ...
# processed_data/2003/tec-symh-2003-05-30-2003-09-26.csv done!
# processed_data/2003/tec-symh-2003-05-03-2003-05-30.csv starting ...
# processed_data/2003/tec-symh-2003-05-03-2003-05-30.csv done!
# processed_data/2003/tec-symh-2003-02-26-2003-03-04.csv starting ...
# processed_data/2003/tec-symh-2003-02-26-2003-03-04.csv done!

# %%
Path("asd/asd/dds").mkdir(parents=True)

# %%
for year in [2000, 2001, 2002, 2003, 2004, 2005, 2017]:
    # load tec
    tec = pd.read_csv(f"parsed_data/tucu-year-{year}.csv", index_col=0, parse_dates=True)
    # load symh
    symh = data_utils.load_symh_wdc(f"sym/ASY-SYM-WDCformat-{year}.dat")
    # merge

    df = pd.merge(left=tec, 
        right=symh, 
        #left_on=tec_selection.index,
        right_on=symh.index, 
        how="left",left_index=True).loc[:,["tec", "symh"]]
